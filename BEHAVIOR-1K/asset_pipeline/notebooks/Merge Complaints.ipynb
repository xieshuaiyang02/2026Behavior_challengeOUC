# %%
import glob, json, tqdm

# %%
jsons = {}
for fn in tqdm.tqdm(
    glob.glob(r"D:\BEHAVIOR-1K\asset_pipeline\cad\objects\*\*\collision_selection.json")
):
    with open(fn) as f:
        jsons.update(json.load(f))

# %%
jsons

# %%
with open(r"D:\collision_selection_merged.json", "w") as f:
    json.dump(jsons, f)
