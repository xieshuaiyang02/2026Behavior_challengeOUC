# %%
from bddl.knowledge_base import *

# %%
import csv

with open(r"D:\bddl\bddl\generated_data\substance_hyperparams.csv", "r") as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        print(int(Synset.get(row[1]) is None))
