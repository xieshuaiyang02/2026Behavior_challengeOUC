# %%
from bddl.knowledge_base import *

# %%
to_prune = [s.name for s in Synset.view_error_unnecessary()]
print(len(to_prune), "synsets to prune")

# %%
import csv

with open(r"D:\bddl\bddl\generated_data\synsets.csv", "r") as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        print(int(row[0] in to_prune))

# %%
Synset.get("melted__swiss_cheese.n.01").derivative_ancestors

# %%
swiss_cheese = Synset.get("swiss_cheese.n.01")
swiss_cheese.derivative_children

# %%
"isopropyl_alcohol.n.01" in to_prune

# %%
"cola.n.02" in to_prune
